# %%
import pandas as pd

df_1 = pd.read_csv('books.csv')
df_2 = pd.read_csv('data.csv')

# %%
df_1.head()
# Out:
#                                                 link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                    title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                            imagelink rating   price  \
# 0  https://books.toscrape.com/media/cache/2c/da/2...  Three  £51.77
# 1  https://books.toscrape.com/media/cache/26/0c/2...    One  £53.74
# 2  https://books.toscrape.com/media/cache/3e/ef/3...    One  £50.10
# 3  https://books.toscrape.com/media/cache/32/51/3...   Four  £47.82
# ...

# %%
df_2.head()
# Out:
#              category price_e_tax price_i_tax     tax  \
# 0              Poetry     Â£51.77     Â£51.77  Â£0.00
# 1  Historical Fiction     Â£53.74     Â£53.74  Â£0.00
# 2             Fiction     Â£50.10     Â£50.10  Â£0.00
# 3             Mystery     Â£47.82     Â£47.82  Â£0.00
# 4             History     Â£54.23     Â£54.23  Â£0.00
#
#                   quantity  reviews
# 0  In stock (22 available)        0
# 1  In stock (20 available)        0
# 2  In stock (20 available)        0
# 3  In stock (20 available)        0
# 4  In stock (20 available)        0

# %%
df = pd.DataFrame()

# %%
df['Title']= df_1['title']
df['category']      = df_2['category']
df['price_e_tax']   = df_2['price_e_tax']
df['price_i_tax']   = df_2['price_i_tax']
df['tax']           = df_2['tax']
df['rating']        = df_1['rating']
df['reviews']       = df_2['reviews']
df['quantity']      = df_2['quantity']
df['stock']         = df_1['availability']

df['book_link']     = df_1['link']
df['img_link']      = df_1['imagelink']

# %%
df.head()
# Out:
#                                    Title            category price_e_tax  \
# 0                   A Light in the Attic              Poetry     Â£51.77
# 1                     Tipping the Velvet  Historical Fiction     Â£53.74
# 2                             Soumission             Fiction     Â£50.10
# 3                          Sharp Objects             Mystery     Â£47.82
# 4  Sapiens: A Brief History of Humankind             History     Â£54.23
#
#   price_i_tax     tax rating  reviews                 quantity     stock  \
# 0     Â£51.77  Â£0.00  Three        0  In stock (22 available)  In stock
# 1     Â£53.74  Â£0.00    One        0  In stock (20 available)  In stock
# 2     Â£50.10  Â£0.00    One        0  In stock (20 available)  In stock
# 3     Â£47.82  Â£0.00   Four        0  In stock (20 available)  In stock
# 4     Â£54.23  Â£0.00   Five        0  In stock (20 available)  In stock
#
#                                            book_link  \
# ...

# %%
df.to_csv('final.csv', index= False)
